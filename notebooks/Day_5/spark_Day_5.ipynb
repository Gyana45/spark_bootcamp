# %%
from pyspark.sql import SparkSession

# %%
spark =SparkSession.\
                    builder.\
                    master("spark://spark-master:7077").\
                    appName("spark_day_5").\
                    getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/17 05:40:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/17 05:40:12 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://4d7a902e21e2:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>spark_day_5</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
schema='order_id int,customer_id int,product_id int,price float, order_date date,order_status string,state string,quantity int'

df = spark.read.format('csv')\
                .option('header','true')\
                .schema(schema)\
                .load('/data/orders_1gb.csv')
