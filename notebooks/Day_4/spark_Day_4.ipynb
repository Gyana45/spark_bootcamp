# %%
from pyspark.sql import SparkSession
spark = SparkSession.\
                builder.\
                master("spark://spark-master:7077").\
                appName("Day_4").\
                getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/11 05:48:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/11 05:48:22 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
orders_rdd = spark.read.format("csv").\
                option().\
                .schema().\
                load("/data/orders_1gb.csv")
